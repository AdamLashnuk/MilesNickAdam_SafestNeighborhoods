# %%
import pandas as pd
import matplotlib as plt
import numpy as np
import csv

# %%
Fire_Incidents = pd.read_csv("Fire_Incidents.csv", index_col = "_id")
Fire_Incidents.head()
# Out:
#         call_no  incident_type        type_description  \
# _id
# 1    F160029985          111.0           Building fire
# 2    F180022058          111.0           Building fire
# 3    F180022102          131.0  Passenger vehicle fire
# 4    F170043431          131.0  Passenger vehicle fire
# 5    F180021111          111.0           Building fire
#
#                                             address  alarms  \
# _id
# 1         800 BLOCK CENTER ST, WILKINSBURG PA 15221       1
# 2          1100 BLOCK JANE ST, WILKINSBURG PA 15221       1
# 3    SB STATE HWY 28 SB AT 31S, PITTSBURGH PA 15212       0
# 4        1700 BLOCK BELLEAU DR, PITTSBURGH PA 15212       0
# 5        2400 BLOCK VILLAGE RD, PITTSBURGH PA 15205       1
#
#               alarm_time primary_unit  census_tract neighborhood  \
# _id
# 1    2016-04-21T05:01:04      231EN16           NaN          NaN
# 2    2018-03-13T08:34:43      231EN16           NaN          NaN
# ...
